# %%
#Imports
import matplotlib.pyplot as plt
import seabreeze
seabreeze.use('pyseabreeze')
import seabreeze.cseabreeze as csb
from seabreeze.spectrometers import list_devices, Spectrometer
from GUI_backend import PL_GUI

# %%
#Seabreeze and specrometer setup
spectrometers = list_devices()
our_spec = [0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 #Seabreeze and specrometer setup
#       2 spectrometers = list_devices()
#       3 our_spec = [0]
# ----> 4 gui = PL_GUI(our_spec)
#       5 gui.show()
#
# File c:\Users\GingerLab\Desktop\in-situ-PL\GUI_backend.py:86, in PL_GUI.__init__(self, spectrometer)
#      83 self.noOfAv = self.noOfAv_input.value
#      85 #Grab data to display from spectrometer
# ---> 86 self.wavelengths = self.spec.wavelengths()
#      87 ydata = self.requestData()
#      89 self.live_data = [np.insert(self.wavelengths, 0, np.inf)]
#
# AttributeError: 'list' object has no attribute 'wavelengths'

# %%
# Out:
# [<SeaBreezeDevice HDX:HDX01238>]
